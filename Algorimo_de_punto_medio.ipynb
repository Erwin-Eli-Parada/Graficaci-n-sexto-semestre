# %% [markdown]
# <a href="https://colab.research.google.com/github/Erwin-Eli-Parada/Graficaci-n-sexto-semestre/blob/main/Algorimo_de_punto_medio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from math import floor
from pylab import *
xinicial =int (input("x incial"))
yinicial =int (input("y incial"))
xfinal =int (input("x final"))
yfinal =int (input("y final"))
 
dx = abs(xfinal-xinicial)
dy = abs(yfinal-yinicial)
xi=xinicial 
yi=yinicial 

if dx > dy:#inciamos preguntando si la diferencia en x es mayor que en Y
  p=(2*dy)-dx
  a=np.zeros((abs(xfinal-xinicial)+1,2))
  a[0][0]=xinicial
  a[0][1]=yinicial
#debido a que hay varios casos en que el usuarios puede introducir los puntos hago una condición para cada combinación
  if xfinal>xinicial and yfinal>yinicial: #si el punto final es mayor en X y en Y que el inicial, este caso se espera que sea el más común
    for i in range (1,dx+1):
      if p<0:
        xi = xi+1
        a[i][0]=xi
        a[i][1]=yi
        linea.append([xi,yi])
        p=p+(2*dy)
      else:
        xi = xi+1
        yi = yi+1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dy)-(2*dx)
  elif xfinal>xinicial and yfinal<yinicial: #si el punto final es mayor en X pero menor en Y que el inicial
    for i in range (1,dx+1):
      if p<0:
        xi = xi+1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dy)
      else:
        xi = xi+1
        yi = yi-1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dy)-(2*dx)
  elif xfinal<xinicial and yfinal>yinicial:#si el punto final es menor en X pero mayor en Y que el inicial
    for i in range (1,dx+1):
      if p<0:
        xi = xi-1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dy)
      else:
        xi = xi-1
        yi = yi+1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dy)-(2*dx)        
  else:#si el punto final es menor en X y menor en Y que el inicial
    for i in range (1,dx+1):
      if p<0:
        xi = xi-1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dy)
      else:
        xi = xi-1
        yi = yi-1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dy)-(2*dx)
else: #Este bloque es representa cuando la diferencia en Y sea mayor que en X
  p=(2*dx)-dy
  a=np.zeros((abs(yfinal-yinicial)+1,2))
  a[0][0]=xinicial
  a[0][1]=yinicial
  if xfinal>xinicial and yfinal>yinicial:#si el punto final es mayor en X y en Y que el inicial, este caso se espera que sea el más común
    for i in range (1,dy+1):
      if p<0:
        yi = yi+1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dx)
      else:
        xi = xi+1
        yi = yi+1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dx)-(2*dy)
  elif xfinal>xinicial and yfinal<yinicial: #si el punto final es mayor en X pero menor en Y que el inicial
    for i in range (1,dy+1):
      if p<0:
        yi = yi-1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dx)
      else:
        xi = xi+1
        yi = yi-1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dx)-(2*dy)
  elif xfinal<xinicial and yfinal>yinicial:#si el punto final es menor en X pero mayor en Y que el inicial
    for i in range (1,dy+1):
      if p<0:
        yi = yi+1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dx)
      else:
        xi = xi-1
        yi = yi+1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dx)-(2*dy)        
  else:#si el punto final es menor en X y menor en Y que el inicial
    for i in range (1,dy+1):
      if p<0:
        yi = yi-1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dx)
      else:
        xi = xi-1
        yi = yi-1
        a[i][0]=xi
        a[i][1]=yi
        p=p+(2*dx)-(2*dy)
print (a)
# Out:
# x incial1
# y incial1
# x final1
# y final5
# [[ 1.  1.]
#  [ 1.  0.]
#  [ 1. -1.]
#  [ 1. -2.]
#  [ 1. -3.]]
